# %% [markdown]
# ![level_05.png](attachment:level_05.png)

# %%
print("Welcome to Level 5!")
direction = ["left", "right", "up", "down"]
while True: 
        try:
            direction1 = input("Which direction? ")
            if direction1 == "up":
                print("You are going the right way.")
                break
            else:
                if direction1 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction2 = input("Which direction? ")
            if direction2 == "left":
                print("You are going the right way.")
                break
            else:
                if direction2 == "up" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction3 = input("Which direction? ")
            if direction3 == "down":
                print("You are going the right way.")
                break
            else:
                if direction3 == "left" or direction1 == "up" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction4 = input("Which direction? ")
            if direction4 == "left":
                print("You are going the right way.")
                break
            else:
                if direction4 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction5 = input("Which direction? ")
            if direction5 == "up":
                print("You are going the right way.")
                break
            else:
                if direction5 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction6 = input("Which direction? ")
            if direction6 == "left":
                print("You are going the right way.")
                break
            else:
                if direction6 == "up" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction7 = input("Which direction? ")
            if direction7 == "up":
                print("You are going the right way.")
                break
            else:
                if direction7 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction8 = input("Which direction? ")
            if direction8 == "right":
                print("You are going the right way.")
                break
            else:
                if direction8 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction9 = input("Which direction? ")
            if direction9 == "down":
                print("You are going the right way.")
                break
            else:
                if direction9 == "left" or direction1 == "up" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction10 = input("Which direction? ")
            if direction10 == "right":
                print("You are going the right way.")
                break
            else:
                if direction10 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction11 = input("Which direction? ")
            if direction11 == "up":
                print("You are going the right way.")
                break
            else:
                if direction11 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction12 = input("Which direction? ")
            if direction12 == "left":
                print("You are going the right way.")
                break
            else:
                if direction12 == "up" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction13 = input("Which direction? ")
            if direction13 == "up":
                print("You are going the right way.")
                break
            else:
                if direction13 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction14 = input("Which direction? ")
            if direction14 == "right":
                print("You are going the right way.")
                break
            else:
                if direction14 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction15 = input("Which direction? ")
            if direction15 == "up":
                print("You are going the right way.")
                break
            else:
                if direction15 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction16 = input("Which direction? ")
            if direction16 == "left":
                print("You are going the right way.")
                break
            else:
                if direction16 == "up" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction17 = input("Which direction? ")
            if direction17 == "up":
                print("You are going the right way.")
                break
            else:
                if direction17 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction18 = input("Which direction? ")
            if direction18 == "left":
                print("You are going the right way.")
                break
            else:
                if direction18 == "up" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction19 = input("Which direction? ")
            if direction19 == "up":
                print("You are going the right way.")
                break
            else:
                if direction19 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction20 = input("Which direction? ")
            if direction20 == "right":
                print("You are going the right way.")
                break
            else:
                if direction20 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction21 = input("Which direction? ")
            if direction21 == "up":
                print("You are going the right way.")
                break
            else:
                if direction21 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction22 = input("Which direction? ")
            if direction22 == "left":
                print("You are going the right way.")
                break
            else:
                if direction22 == "up" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction23 = input("Which direction? ")
            if direction23 == "down":
                print("You are going the right way.")
                break
            else:
                if direction23 == "left" or direction1 == "up" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction24 = input("Which direction? ")
            if direction24 == "left":
                print("You are going the right way.")
                break
            else:
                if direction24 == "up" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction25 = input("Which direction? ")
            if direction25 == "up":
                print("You are going the right way.")
                break
            else:
                if direction25 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction26 = input("Which direction? ")
            if direction26 == "right":
                print("You are going the right way.")
                break
            else:
                if direction26 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction27 = input("Which direction? ")
            if direction27 == "up":
                print("You are going the right way.")
                break
            else:
                if direction27 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction28 = input("Which direction? ")
            if direction28 == "right":
                print("You are going the right way.")
                break
            else:
                if direction28 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction29 = input("Which direction? ")
            if direction29 == "up":
                print("You are going the right way.")
                break
            else:
                if direction29 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction30 = input("Which direction? ")
            if direction30 == "right":
                print("You are going the right way.")
                break
            else:
                if direction30 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction31 = input("Which direction? ")
            if direction31 == "down":
                print("You are going the right way.")
                break
            else:
                if direction31 == "left" or direction1 == "up" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction32 = input("Which direction? ")
            if direction32 == "left":
                print("You are going the right way.")
                break
            else:
                if direction32 == "up" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction33 = input("Which direction? ")
            if direction33 == "down":
                print("You are going the right way.")
                break
            else:
                if direction33 == "left" or direction1 == "up" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction34 = input("Which direction? ")
            if direction34 == "right":
                print("You are going the right way.")
                break
            else:
                if direction34 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction35 = input("Which direction? ")
            if direction35 == "up":
                print("You are going the right way.")
                break
            else:
                if direction35 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction36 = input("Which direction? ")
            if direction36 == "right":
                print("You are going the right way.")
                break
            else:
                if direction36 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction37 = input("Which direction? ")
            if direction37 == "up":
                print("You are going the right way.")
                break
            else:
                if direction37 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction38 = input("Which direction? ")
            if direction38 == "left":
                print("You are going the right way.")
                break
            else:
                if direction38 == "up" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction39 = input("Which direction? ")
            if direction39 == "up":
                print("You are going the right way.")
                break
            else:
                if direction39 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction40 = input("Which direction? ")
            if direction40 == "right":
                print("You are going the right way.")
                break
            else:
                if direction40 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way.")
        except:
            print("come on")
while True: 
        try:
            direction41 = input("Which direction? ")
            if direction41 == "up":
                print("You are going the right way.")
                break
            else:
                if direction41 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way.")
        except:
            print("come on")
print("YOU HAVE COMPLETED LEVEL 5!")
# Out:
# Welcome to Level 5!
# Which direction? UP
# Which direction? right
# You are going the wrong way.
# Which direction? up
# You are going the right way.
