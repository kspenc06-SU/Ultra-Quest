# %%
print("Welcome to level 1: ")
direction = ("left","right","up","down")
while True:
        try:
            direction1 = input("which direction:")
            if direction1 == "up":
                print("your going the right way")
                break
            else:
                if direction1 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction2 = input("which direction:")
            if direction2 == "right":
                print("your going the right way")
                break
            else:
                if direction2 == "left" or direction2 == "down" or direction2 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction3 = input("which direction:")
            if direction3 == "up":
                print("your going the right way")
                break
            else:
                if direction3 == "left" or direction3 == "right" or direction3 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction4 = input("which direction:")
            if direction4 == "right":
                print("your going the right way")
                break
            else:
                if direction4 == "down" or direction4 == "left" or direction4 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction5 = input("which direction:")
            if direction5 == "down":
                print("your going the right way")
                break
            else:
                if direction5 == "left" or direction5 == "right" or direction5 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction6 = input("which direction:")
            if direction6 == "right":
                print("your going the right way")
                break
            else:
                if direction6 == "down" or direction6 == "left" or direction6 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction7 = input("which direction:")
            if direction7 == "up":
                print("your going the right way")
                break
            else:
                if direction7 == "left" or direction7 == "right" or direction7 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction8 = input("which direction:")
            if direction8 == "left":
                print("your going the right way")
                break
            else:
                if direction8 == "up" or direction8 == "right" or direction8 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction9 = input("which direction:")
            if direction9 == "up":
                print("your going the right way")
                break
            else:
                if direction9 == "left" or direction9 == "right" or direction9 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction10 = input("which direction:")
            if direction10 == "right":
                print("your going the right way")
                break
            else:
                if direction10 == "left" or direction10 == "down" or direction10 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction11 = input("which direction:")
            if direction11 == "up":
                print("your going the right way")
                break
            else:
                if direction11 == "left" or direction11 == "right" or direction11 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction12 = input("which direction:")
            if direction12 == "left":
                print("your going the right way")
                break
            else:
                if direction12 == "down" or direction12 == "right" or direction12 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction13 = input("which direction:")
            if direction13 == "down":
                print("your going the right way")
                break
            else:
                if direction13 == "left" or direction13 == "right" or direction13 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction14 = input("which direction:")
            if direction14 == "left":
                print("your going the right way")
                break
            else:
                if direction14 == "down" or direction14 == "right" or direction14 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction15 = input("which direction:")
            if direction15 == "up":
                print("your going the right way")
                break
            else:
                if direction15 == "left" or direction15 == "right" or direction15 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction16 = input("which direction:")
            if direction16 == "left":
                print("your going the right way")
                break
            else:
                if direction16 == "right" or direction16 == "down" or direction16 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction17 = input("which direction:")
            if direction17 == "down":
                print("your going the right way")
                break
            else:
                if direction17 == "left" or direction17 == "right" or direction17 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction18 = input("which direction:")
            if direction18 == "left":
                print("your going the right way")
                break
            else:
                if direction18 == "right" or direction18 == "down" or direction18 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction19 = input("which direction:")
            if direction19 == "up":
                print("your going the right way")
                break
            else:
                if direction19 == "left" or direction19 == "right" or direction19 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction20 = input("which direction:")
            if direction20 == "right":
                print("your going the right way")
                break
            else:
                if direction20 == "left" or direction20 == "down" or direction20 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction21 = input("which direction:")
            if direction21 == "up":
                print("your going the right way")
                break
            else:
                if direction21 == "left" or direction21 == "right" or direction21 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction22 = input("which direction:")
            if direction22 == "left":
                print("your going the right way")
                break
            else:
                if direction22 == "down" or direction22 == "right" or direction22 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction23 = input("which direction:")
            if direction23 == "up":
                print("your going the right way")
                break
            else:
                if direction23 == "left" or direction23 == "right" or direction23 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
