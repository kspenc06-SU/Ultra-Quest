# %%
print("Welcome to Level 4!")
    direction = ("left","right","up","down")
    while True: 
         try:
                direction1 = input(\"Which direction? \")
                if direction1 == \"left\": ",
                    print(\"You are going the right way.\")
                    break 
                else:
                    if direction1 == \"right\" or direction1 == \"down\" or direction1 == \"up\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
            direction2 = input(\"Which direction? \")
                if direction2 == \"up\":
                   print(\"You are going the right way.\")
                    break
                else:
                    if direction2 == \"left\" or direction1 == \"down\" or direction1 == \"right\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction3 = input(\"Which direction? \")
                if direction3 == \"left\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction3 == \"right\" or direction1 == \"down\" or direction1 == \"right\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction4 = input(\"Which direction? \")
                if direction4 == \"up\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction4 == \"left\" or direction1 == \"down\" or direction1 == \"right\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction5 = input(\"Which direction? \")
                if direction5 == \"right\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction5 == \"left\" or direction1 == \"down\" or direction1 == \"up\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction6 = input(\"Which direction? \")
                if direction6 == \"up\":
                    print(\"You are going the right way.\")
                break
                else:
                    if direction6 == \"left\" or direction1 == \"down\" or direction1 == \"right\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction7 = input(\"Which direction? \")
            if direction7 == \"left\":
                    print(\"You are going the right way.\")
                    break
            else:
                    if direction7 == \"right\" or direction1 == \"down\" or direction1 == \"up\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction8 = input(\"Which direction? \")
                if direction8 == \"up\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction2 == \"left\" or direction1 == \"down\" or direction1 == \"right\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction9 = input(\"Which direction? \")
                if direction9 == \"right\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction9 == \"left\" or direction1 == \"down\" or direction1 == \"up\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction10 = input(\"Which direction? \")
                if direction10 == \"up\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction10 == \"left\" or direction1 == \"down\" or direction1 == \"right\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction11 = input(\"Which direction? \")
                if direction11 == \"right\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction11 == \"left\" or direction1 == \"down\" or direction1 == \"up\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction12 = input(\"Which direction? \")
                if direction12 == \"down\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction12 == \"left\" or direction1 == \"up\" or direction1 == \"right\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction13 = input(\"Which direction? \")
                if direction13 == \"right\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction13 == \"left\" or direction1 == \"down\" or direction1 == \"up\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction14 = input(\"Which direction? \")
                if direction14 == \"down\":
                    print(\"You are going the right way.\")
                    break
            else:
                    if direction14 == \"left\" or direction1 == \"up\" or direction1 == \"right\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction15 = input(\"Which direction? \")
            if direction15 == \"right\":
                    print(\"You are going the right way.\")
                    break
                else:
                    if direction15 == \"left\" or direction1 == \"down\" or direction1 == \"up\":
                        print(\"You are going the wrong way.\")
            except:
                print(\"come on\")
    while True:
            try:
                direction16 = input(\"Which direction? \") 
                if direction16 == \"up\": ",
                    print(\"You are going the right way.\") ",
                    break ",
                else: ",
                    if direction16 == \"left\" or direction1 == \"down\" or direction1 == \"right\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction17 = input(\"Which direction? \") ",
                if direction17 == \"left\": ",
                    print(\"You are going the right way.\") ",
                break ",
                else: ",
                    if direction17 == \"up\" or direction1 == \"down\" or direction1 == \"right\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction18 = input(\"Which direction? \") ",
                if direction18 == \"up\": ",
                    print(\"You are going the right way.\") ",
                    break ",
                else: ",
                    if direction18 == \"left\" or direction1 == \"down\" or direction1 == \"right\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction19 = input(\"Which direction? \") ",
                if direction19 == \"left\": ",
                    print(\"You are going the right way.\") ",
                    break ",
                else: ",
                    if direction19 == \"up\" or direction1 == \"down\" or direction1 == \"right\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction20 = input(\"Which direction? \") ",
                if direction20 == \"up\": ",
                    print(\"You are going the right way.\") ",
                    break ",
                else: ",
                    if direction20 == \"left\" or direction1 == \"down\" or direction1 == \"right\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction21 = input(\"Which direction? \") ",
                if direction21 == \"right\": ",
                    print(\"You are going the right way.\") ",
                    break ",
                else: ",
                    if direction21 == \"left\" or direction1 == \"down\" or direction1 == \"up\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction22 = input(\"Which direction? \") ",
                if direction22 == \"down\": ",
                    print(\"You are going the right way.\") ",
                    break ",
                else: ",
                    if direction22 == \"left\" or direction1 == \"up\" or direction1 == \"right\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction23 = input(\"Which direction? \") ",
                if direction23 == \"right\": ",
                    print(\"You are going the right way.\") ",
                    break ",
                else: ",
                    if direction23 == \"left\" or direction1 == \"down\" or direction1 == \"up\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction24 = input(\"Which direction? \") ",
                if direction24 == \"up\": ",
                    print(\"You are going the right way.\") ",
                    break ",
                else: ",
                    if direction24 == \"left\" or direction1 == \"down\" or direction1 == \"right\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction25 = input(\"Which direction? \") ",
                if direction25 == \"left\": ",
                    print(\"You are going the right way.\") ",
                       break ",
                else: ",
                    if direction25 == \"up\" or direction1 == \"down\" or direction1 == \"right\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    while True:  ",
            try: ",
                direction26 = input(\"Which direction? \") ",
                if direction26 == \"up\": ",
                    print(\"You are going the right way.\") ",
                    break ",
                else: ",
                    if direction26 == \"left\" or direction1 == \"down\" or direction1 == \"right\": ",
                        print(\"You are going the wrong way.\") ",
            except: ",
                print(\"come on\") ",
    print(\"YOU HAVE COMPLETED LEVEL 4!\")"
# Out:
#   File "<ipython-input-1-599d0d2a1834>", line 1
#     print(\"Welcome to Level 4!\")\n",
#                                       ^
# SyntaxError: unexpected character after line continuation character
