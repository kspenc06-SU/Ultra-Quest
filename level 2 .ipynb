# %% [markdown]
# ![level_02.png](attachment:level_02.png)

# %%
print("Welcome to level 2: ")
direction = ("left","right","up","down")
while True:
        try:
            direction1 = input("which direction:")
            if direction1 == "up":
                print("your going the right way")
                break
            else:
                if direction1 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction2 = input("which direction:")
            if direction2 == "left":
                print("your going the right way")
                break
            else:
                if direction2 == "right" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction3 = input("which direction:")
            if direction3 == "up":
                print("your going the right way")
                break
            else:
                if direction3 == "left" or direction1 == "right" or direction1 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction4 = input("which direction:")
            if direction4 == "left":
                print("your going the right way")
                break
            else:
                if direction4 == "down" or direction1 == "right" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction5 = input("which direction:")
            if direction5 == "up":
                print("your going the right way")
                break
            else:
                if direction5 == "left" or direction1 == "right" or direction1 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction6 = input("which direction:")
            if direction6 == "left":
                print("your going the right way")
                break
            else:
                if direction6 == "down" or direction1 == "right" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction7 = input("which direction:")
            if direction7 == "up":
                print("your going the right way")
                break
            else:
                if direction7 == "left" or direction1 == "right" or direction1 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction8 = input("which direction:")
            if direction8 == "left":
                print("your going the right way")
                break
            else:
                if direction8 == "up" or direction1 == "right" or direction1 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction9 = input("which direction:")
            if direction9 == "down":
                print("your going the right way")
                break
            else:
                if direction9 == "left" or direction1 == "right" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction10 = input("which direction:")
            if direction10 == "right":
                print("your going the right way")
                break
            else:
                if direction10 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction11 = input("which direction:")
            if direction11 == "down":
                print("your going the right way")
                break
            else:
                if direction11 == "left" or direction1 == "right" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction12 = input("which direction:")
            if direction12 == "left":
                print("your going the right way")
                break
            else:
                if direction12 == "down" or direction1 == "right" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction13 = input("which direction:")
            if direction13 == "down":
                print("your going the right way")
                break
            else:
                if direction13 == "left" or direction1 == "right" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction14 = input("which direction:")
            if direction14 == "left":
                print("your going the right way")
                break
            else:
                if direction14 == "down" or direction1 == "right" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction15 = input("which direction:")
            if direction15 == "up":
                print("your going the right way")
                break
            else:
                if direction15 == "left" or direction1 == "right" or direction1 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction16 = input("which direction:")
            if direction16 == "right":
                print("your going the right way")
                break
            else:
                if direction16 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction17 = input("which direction:")
            if direction17 == "down":
                print("your going the right way")
                break
            else:
                if direction17 == "left" or direction1 == "right" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction18 = input("which direction:")
            if direction18 == "right":
                print("your going the right way")
                break
            else:
                if direction18 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction19 = input("which direction:")
            if direction19 == "up":
                print("your going the right way")
                break
            else:
                if direction19 == "left" or direction1 == "right" or direction1 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction20 = input("which direction:")
            if direction20 == "right":
                print("your going the right way")
                break
            else:
                if direction20 == "left" or direction1 == "down" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction21 = input("which direction:")
            if direction21 == "up":
                print("your going the right way")
                break
            else:
                if direction21 == "left" or direction1 == "right" or direction1 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction22 = input("which direction:")
            if direction22 == "left":
                print("your going the right way")
                break
            else:
                if direction22 == "down" or direction1 == "right" or direction1 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
while True:
        try:
            direction23 = input("which direction:")
            if direction23 == "up":
                print("your going the right way")
                break
            else:
                if direction23 == "left" or direction1 == "right" or direction1 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
# Out:
# Welcome to level 2:
# which direction:left
# You are going the wrong way
# which direction:right
# You are going the wrong way
# which direction:up
# your going the right way
# which direction:DOWN
# You are going the wrong way
