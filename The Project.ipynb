# %%
print("Welcome to round 3: ")
direction = ("left","right","up","down")


def Maze_3:
    while True: 
        #try:
        direction1 = input("which direction:")
        if direction1 == "up":
            print("your going the right way \n", "-"*40)
            break
        elif direction1 == "left" or direction1 == "down" or direction1 == "right":
            print("You are going the wrong way")
        else:
            print("come on")
        #except:
            #print("come on")
            #break
    while True: 
        try:
            direction2 = input("which direction")
            if direction2 == "left":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction2 == "right" or direction2 == "down" or direction2 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction3 = input("which direction")
            if direction3 == "up":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction3 == "left" or direction3 == "down" or direction3 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction4 = input("which direction")
            if direction4 == "left":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction4 == "right" or direction4 == "down" or direction4 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction5 = input("which direction")
            if direction5 == "up":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction5 == "left" or direction5 == "down" or direction5 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction6 = input("which direction")
            if direction6 == "right":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction6 == "left" or direction6 == "down" or direction6 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction7 = input("which direction")
            if direction7 == "up":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction7 == "left" or direction7 == "down" or direction7 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction8 = input("which direction")
            if direction8 == "left":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction8 == "right" or direction8 == "down" or direction8 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction9 = input("which direction")
            if direction9 == "up":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction9 == "right" or direction9 == "down" or direction9 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction10 = input("which direction")
            if direction10 == "right":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction10 == "left" or direction10 == "down" or direction10 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction11 = input("which direction")
            if direction11 == "up":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction11 == "right" or direction11 == "down" or direction11 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction12 = input("which direction")
            if direction12 == "right":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction12 == "left" or direction12 == "down" or direction12 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction13 = input("which direction")
            if direction13 == "down":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction13 == "right" or direction13 == "left" or direction13 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction14 = input("which direction")
            if direction14 == "right":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction14 == "left" or direction14 == "down" or direction14 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction15 = input("which direction")
            if direction15 == "up":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction15 == "right" or direction15 == "down" or direction15 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction16 = input("which direction")
            if direction16 == "right":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction16 == "left" or direction16 == "down" or direction16 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction17 = input("which direction")
            if direction17 == "up":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction17 == "right" or direction17 == "down" or direction17 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")

    while True: 
        try:
            direction18 = input("which direction")
            if direction18 == "right":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction18 == "up" or direction17 == "down" or direction17 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")

    while True: 
        try:
            direction19 = input("which direction")
            if direction19 == "up":
                print("your going the right way \n", "-"*40)
                break
            else:
                if direction19 == "right" or direction19 == "down" or direction19 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    print("YOU WIN")
# Out:
# Welcome to round 2:
# which direction:dshhls
# come on
# which direction:up
# your going the right way
#  ----------------------------------------
# which directiondsfaddd

# %%
def Maze_4:    
    while True: 
        try:
            direction1 = input("which direction:")
            if direction1 == "up":
                print("your going the right way")
                break
            else:
                if direction1 == "left" or direction1 == "down" or direction1 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction2 = input("which direction")
            if direction2 == "right":
                print("your going the right way")
                break
            else:
                if direction2 == "left" or direction2 == "down" or direction2 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction3 = input("which direction")
            if direction3 == "down":
                print("your going the right way")
                break
            else:
                if direction3 == "left" or direction3 == "up" or direction3 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction4 = input("which direction")
            if direction4 == "right":
                print("your going the right way")
                break
            else:
                if direction4 == "left" or direction4 == "down" or direction4 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction5 = input("which direction")
            if direction5 == "up":
                print("your going the right way")
                break
            else:
                if direction5 == "left" or direction5 == "down" or direction5 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction6 = input("which direction")
            if direction6 == "right":
                print("your going the right way")
                break
            else:
                if direction6 == "left" or direction6 == "down" or direction6 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction7 = input("which direction")
            if direction7 == "down":
                print("your going the right way")
                break
            else:
                if direction7 == "left" or direction7 == "up" or direction7 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction8 = input("which direction")
            if direction8 == "right":
                print("your going the right way")
                break
            else:
                if direction8 == "left" or direction8 == "down" or direction8 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction9 = input("which direction")
            if direction9 == "up":
                print("your going the right way")
                break
            else:
                if direction9 == "right" or direction9 == "down" or direction9 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction10 = input("which direction")
            if direction10 == "right":
                print("your going the right way")
                break
            else:
                if direction10 == "left" or direction10 == "down" or direction10 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction11 = input("which direction")
            if direction11 == "up":
                print("your going the right way")
                break
            else:
                if direction11 == "right" or direction11 == "down" or direction11 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction12 = input("which direction")
            if direction12 == "left":
                print("your going the right way")
                break
            else:
                if direction12 == "right" or direction12 == "down" or direction12 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction13 = input("which direction")
            if direction13 == "up":
                print("your going the right way")
                break
            else:
                if direction13 == "right" or direction13 == "left" or direction13 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction14 = input("which direction")
            if direction14 == "right":
                print("your going the right way")
                break
            else:
                if direction14 == "left" or direction14 == "down" or direction14 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction15 = input("which direction")
            if direction15 == "up":
                print("your going the right way")
                break
            else:
                if direction15 == "right" or direction15 == "down" or direction15 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction16 = input("which direction")
            if direction16 == "left":
                print("your going the right way")
                break
            else:
                if direction16 == "right" or direction16 == "down" or direction16 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction17 = input("which direction")
            if direction17 == "down":
                print("your going the right way")
                break
            else:
                if direction17 == "right" or direction17 == "up" or direction17 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")

    while True: 
        try:
            direction18 = input("which direction")
            if direction18 == "left":
                print("your going the right way")
                break
            else:
                if direction18 == "up" or direction17 == "down" or direction17 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")

    while True: 
        try:
            direction19 = input("which direction")
            if direction19 == "down":
                print("your going the right way")
                break
            else:
                if direction19 == "right" or direction19 == "up" or direction19 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction20 = input("which direction:")
            if direction20 == "right":
                print("your going the right way")
                break
            else:
                if direction20 == "left" or direction20 == "down" or direction20 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction21 = input("which direction")
            if direction21 == "down":
                print("your going the right way")
                break
            else:
                if direction21 == "left" or direction21 == "right" or direction21 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction22 = input("which direction")
            if direction22 == "left":
                print("your going the right way")
                break
            else:
                if direction22 == "down" or direction22 == "up" or direction22 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction23 = input("which direction")
            if direction23 == "down":
                print("your going the right way")
                break
            else:
                if direction23 == "left" or direction23 == "right" or direction23 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction24 = input("which direction")
            if direction24 == "left":
                print("your going the right way")
                break
            else:
                if direction24 == "up" or direction24 == "down" or direction24 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction25 = input("which direction")
            if direction25 == "up":
                print("your going the right way")
                break
            else:
                if direction25 == "left" or direction25 == "down" or direction25 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction26 = input("which direction")
            if direction26 == "right":
                print("your going the right way")
                break
            else:
                if direction26 == "left" or direction26 == "up" or direction26 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction27 = input("which direction")
            if direction27 == "up":
                print("your going the right way")
                break
            else:
                if direction27 == "left" or direction27 == "down" or direction27 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction28 = input("which direction")
            if direction28 == "left":
                print("your going the right way")
                break
            else:
                if direction28 == "right" or direction28 == "down" or direction28 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction29 = input("which direction")
            if direction29 == "up":
                print("your going the right way")
                break
            else:
                if direction29 == "left" or direction29 == "down" or direction29 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction30 = input("which direction")
            if direction30 == "up":
                print("your going the right way")
                break
            else:
                if direction30 == "right" or direction30 == "down" or direction30 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction31 = input("which direction")
            if direction31 == "left":
                print("your going the right way")
                break
            else:
                if direction31 == "right" or direction31 == "down" or direction30 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction32 = input("which direction")
            if direction32 == "up":
                print("your going the right way")
                break
            else:
                if direction32 == "right" or direction32 == "left" or direction31 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction33 = input("which direction")
            if direction33 == "right":
                print("your going the right way")
                break
            else:
                if direction33 == "left" or direction33 == "down" or direction33 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction34 = input("which direction")
            if direction34 == "up":
                print("your going the right way")
                break
            else:
                if direction34 == "right" or direction34 == "down" or direction34 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction35 = input("which direction")
            if direction35 == "left":
                print("your going the right way")
                break
            else:
                if direction35 == "right" or direction35 == "down" or direction35 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction36 = input("which direction")
            if direction36 == "down":
                print("your going the right way")
                break
            else:
                if direction36 == "right" or direction36 == "up" or direction36 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")

    while True: 
        try:
            direction37 = input("which direction")
            if direction37 == "left":
                print("your going the right way")
                break
            else:
                if direction37 == "up" or direction37 == "down" or direction37 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")

    while True: 
        try:
            direction38 = input("which direction")
            if direction38 == "down":
                print("your going the right way")
                break
            else:
                if direction38 == "right" or direction38 == "up" or direction38 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction39 = input("which direction:")
            if direction39 == "up":
                print("your going the right way")
                break
            else:
                if direction39 == "left" or direction39 == "down" or direction39 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction40 = input("which direction")
            if direction40 == "right":
                print("your going the right way")
                break
            else:
                if direction40 == "left" or direction40 == "down" or direction40 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction41 = input("which direction")
            if direction41 == "down":
                print("your going the right way")
                break
            else:
                if direction41 == "left" or direction41 == "up" or direction41 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction42 = input("which direction")
            if direction42 == "right":
                print("your going the right way")
                break
            else:
                if direction42 == "left" or direction42 == "down" or direction42 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction43 = input("which direction")
            if direction43 == "up":
                print("your going the right way")
                break
            else:
                if direction43 == "left" or direction43 == "down" or direction43 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction44 = input("which direction")
            if direction44 == "right":
                print("your going the right way")
                break
            else:
                if direction44 == "left" or direction44 == "down" or direction44 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction45 = input("which direction")
            if direction45 == "down":
                print("your going the right way")
                break
            else:
                if direction45 == "left" or direction45 == "up" or direction45 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")

    while True: 
        try:
            direction46 = input("which direction")
            if direction46 == "up":
                print("your going the right way")
                break
            else:
                if direction46 == "right" or direction46 == "down" or direction46 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction47 = input("which direction")
            if direction47 == "right":
                print("your going the right way")
                break
            else:
                if direction47 == "left" or direction47 == "down" or direction47 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction48 = input("which direction")
            if direction48 == "up":
                print("your going the right way")
                break
            else:
                if direction48 == "right" or direction48 == "down" or direction48 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction49 = input("which direction")
            if direction49 == "left":
                print("your going the right way")
                break
            else:
                if direction49 == "right" or direction49 == "down" or direction49 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction50 = input("which direction")
            if direction50 == "up":
                print("your going the right way")
                break
            else:
                if direction50 == "right" or direction50 == "left" or direction50 == "down":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction51 = input("which direction")
            if direction51 == "right":
                print("your going the right way")
                break
            else:
                if direction51 == "left" or direction51 == "down" or direction51 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction52 = input("which direction")
            if direction52 == "up":
                print("your going the right way")
                break
            else:
                if direction52 == "right" or direction52 == "down" or direction52 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction53 = input("which direction")
            if direction53 == "left":
                print("your going the right way")
                break
            else:
                if direction53 == "right" or direction53 == "down" or direction53 == "up":
                    print("You are going the wrong way")
        except:
            print("come on")
    while True: 
        try:
            direction54 = input("which direction")
            if direction54 == "down":
                print("your going the right way")
                break
            else:
                if direction54 == "right" or direction54 == "up" or direction54 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")

    while True: 
        try:
            direction18 = input("which direction")
            if direction18 == "left":
                print("your going the right way")
                break
            else:
                if direction18 == "up" or direction17 == "down" or direction17 == "right":
                    print("You are going the wrong way")
        except:
            print("come on")

    while True: 
        try:
            direction19 = input("which direction")
            if direction19 == "down":
                print("your going the right way")
                break
            else:
                if direction19 == "right" or direction19 == "up" or direction19 == "left":
                    print("You are going the wrong way")
        except:
            print("come on")
    print("YOU WIN")

# %%
if
